# %%
import win32api
import win32con
import cv2 as cv
import numpy as np


def get_roi(frame, x1, x2, y1, y2):
    dst = frame[y1:y2, x1:x2]
    cv.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), thickness=2)
    return dst


if __name__ == "__main__":

    capture = cv.VideoCapture(0)
    m_0 = 0
    m_1 = 0
    m_2 = 0
    m_3 = 0
    m_4 = 0
    m_5 = 0
    m_6 = 0
    m_7 = 0
    m_8 = 0
    m_9 = 0

    while True:

        ret, frame = capture.read()
        roi = get_roi(frame, 100, 300, 100, 300)
        k = cv.waitKey(50)
        if k == 27:  # 按下ESC退出
            break
        elif k == ord('a'):                 # 按下'A'会保存当前图片到指定目录下 
            cv.imwrite("data/0/%s.jpg" % m_0, roi)
            m_0 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\0\\%s.jpg" % m_0, flip_image)
            # m_0 += 1
            print('正在保存0-roi图片,本次图片数量:', m_0)
        elif k == ord('s'):  
            cv.imwrite("data/1/%s.jpg" % m_1, roi)
            m_1 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\1\\%s.jpg" % m_1, flip_image)
            # m_1 += 1
            print('正在保存1-roi图片,本次图片数量:', m_1)
        elif k == ord('d'):  
            cv.imwrite("data/2/%s.jpg" % m_2, roi)
            m_2 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\2\\%s.jpg" % m_2, flip_image)
            # m_2 += 1
            print('正在保存2-roi图片,本次图片数量:', m_2)
        elif k == ord('f'):  
            cv.imwrite("data/3/%s.jpg" % m_3, roi)
            m_3 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\3\\%s.jpg" % m_3, flip_image)
            # m_3 += 1
            print('正在保存3-roi图片,本次图片数量:', m_3)
        elif k == ord('g'):  
            cv.imwrite("data/4/%s.jpg" % m_4, roi)
            m_4 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\4\\%s.jpg" % m_4, flip_image)
            # m_4 += 1
            print('正在保存4-roi图片,本次图片数量:', m_4)
        elif k == ord('h'):  
            cv.imwrite("data/5/%s.jpg" % m_5, roi)
            m_5 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\5\\%s.jpg" % m_5, flip_image)
            # m_5 += 1
            print('正在保存5-roi图片,本次图片数量:', m_5)
        elif k == ord('j'):  
            cv.imwrite("data/6/%s.jpg" % m_6, roi)
            m_6 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\6\\%s.jpg" % m_6, flip_image)
            # m_6 += 1
            print('正在保存6-roi图片,本次图片数量:', m_6)
        elif k == ord('k'):  
            cv.imwrite("data/7/%s.jpg" % m_7, roi)
            m_7 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\7\\%s.jpg" % m_7, flip_image)
            # m_7 += 1
            print('正在保存7-roi图片,本次图片数量:', m_7)
        elif k == ord('l'):  
            cv.imwrite("data/8/%s.jpg" % m_8, roi)
            m_8 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\8\\%s.jpg" % m_8, flip_image)
            # m_8 += 1
            print('正在保存8-roi图片,本次图片数量:', m_8)
        elif k == ord('z'):  
            cv.imwrite("data/9/%s.jpg" % m_9, roi)
            m_9 += 1
            # flip_image = cv.flip(skin, 1)  # 这里用到的是水平翻转，因为后面的参数是一
            # cv.imwrite("E:\\aiFile\\picture\\gesture_data\\9\\%s.jpg" % m_9, flip_image)
            # m_9 += 1
            print('正在保存9-roi图片,本次图片数量:', m_9)
        cv.imshow("roi", roi)
        cv.imshow("frame", frame)
        c = cv.waitKey(50)
        if c == 27:
            break
    cv.waitKey(0)
    capture.release()
    cv.destroyAllWindows()
# Out:
# 正在保存9-roi图片,本次图片数量: 1
# 正在保存9-roi图片,本次图片数量: 2
# 正在保存9-roi图片,本次图片数量: 3
# 正在保存9-roi图片,本次图片数量: 4
# 正在保存9-roi图片,本次图片数量: 5
# 正在保存9-roi图片,本次图片数量: 6
# 正在保存9-roi图片,本次图片数量: 7
# 正在保存9-roi图片,本次图片数量: 8
# 正在保存9-roi图片,本次图片数量: 9
# 正在保存9-roi图片,本次图片数量: 10
# 正在保存9-roi图片,本次图片数量: 11
# 正在保存9-roi图片,本次图片数量: 12
# 正在保存9-roi图片,本次图片数量: 13
# 正在保存9-roi图片,本次图片数量: 14
# 正在保存9-roi图片,本次图片数量: 15
# 正在保存9-roi图片,本次图片数量: 16
# 正在保存9-roi图片,本次图片数量: 17
# 正在保存9-roi图片,本次图片数量: 18
# 正在保存9-roi图片,本次图片数量: 19
# 正在保存9-roi图片,本次图片数量: 20
# 正在保存9-roi图片,本次图片数量: 21
# 正在保存9-roi图片,本次图片数量: 22
# 正在保存9-roi图片,本次图片数量: 23
# 正在保存9-roi图片,本次图片数量: 24
# 正在保存9-roi图片,本次图片数量: 25
# 正在保存9-roi图片,本次图片数量: 26
# 正在保存9-roi图片,本次图片数量: 27
# 正在保存9-roi图片,本次图片数量: 28
# 正在保存9-roi图片,本次图片数量: 29
# 正在保存9-roi图片,本次图片数量: 30
# 正在保存9-roi图片,本次图片数量: 31
# 正在保存9-roi图片,本次图片数量: 32
# 正在保存9-roi图片,本次图片数量: 33
# 正在保存9-roi图片,本次图片数量: 34
# 正在保存9-roi图片,本次图片数量: 35
# 正在保存9-roi图片,本次图片数量: 36
# 正在保存9-roi图片,本次图片数量: 37
# 正在保存9-roi图片,本次图片数量: 38
# 正在保存9-roi图片,本次图片数量: 39
# 正在保存9-roi图片,本次图片数量: 40
# 正在保存9-roi图片,本次图片数量: 41
# 正在保存9-roi图片,本次图片数量: 42
# 正在保存9-roi图片,本次图片数量: 43
# 正在保存9-roi图片,本次图片数量: 44
# 正在保存9-roi图片,本次图片数量: 45
# 正在保存9-roi图片,本次图片数量: 46
# 正在保存9-roi图片,本次图片数量: 47
# 正在保存9-roi图片,本次图片数量: 48
# 正在保存9-roi图片,本次图片数量: 49
# 正在保存9-roi图片,本次图片数量: 50
# 正在保存9-roi图片,本次图片数量: 51
# 正在保存9-roi图片,本次图片数量: 52
# 正在保存9-roi图片,本次图片数量: 53
# 正在保存9-roi图片,本次图片数量: 54
# 正在保存9-roi图片,本次图片数量: 55
# 正在保存9-roi图片,本次图片数量: 56
# 正在保存9-roi图片,本次图片数量: 57
# 正在保存9-roi图片,本次图片数量: 58
# 正在保存9-roi图片,本次图片数量: 59
# 正在保存9-roi图片,本次图片数量: 60
# 正在保存9-roi图片,本次图片数量: 61
# 正在保存9-roi图片,本次图片数量: 62
# 正在保存9-roi图片,本次图片数量: 63
# 正在保存9-roi图片,本次图片数量: 64
# 正在保存9-roi图片,本次图片数量: 65
# 正在保存9-roi图片,本次图片数量: 66
# 正在保存9-roi图片,本次图片数量: 67
# 正在保存9-roi图片,本次图片数量: 68
# 正在保存9-roi图片,本次图片数量: 69
# 正在保存9-roi图片,本次图片数量: 70
# 正在保存9-roi图片,本次图片数量: 71
# 正在保存9-roi图片,本次图片数量: 72
# 正在保存9-roi图片,本次图片数量: 73
# 正在保存9-roi图片,本次图片数量: 74
# 正在保存9-roi图片,本次图片数量: 75
# 正在保存9-roi图片,本次图片数量: 76
# 正在保存9-roi图片,本次图片数量: 77
# 正在保存9-roi图片,本次图片数量: 78
# 正在保存9-roi图片,本次图片数量: 79
# 正在保存9-roi图片,本次图片数量: 80
# 正在保存9-roi图片,本次图片数量: 81
# 正在保存9-roi图片,本次图片数量: 82
# 正在保存9-roi图片,本次图片数量: 83
# 正在保存9-roi图片,本次图片数量: 84
# 正在保存9-roi图片,本次图片数量: 85
# 正在保存9-roi图片,本次图片数量: 86
# 正在保存9-roi图片,本次图片数量: 87
# 正在保存9-roi图片,本次图片数量: 88
# 正在保存9-roi图片,本次图片数量: 89
# 正在保存9-roi图片,本次图片数量: 90
# 正在保存9-roi图片,本次图片数量: 91
# 正在保存9-roi图片,本次图片数量: 92
# 正在保存9-roi图片,本次图片数量: 93
# 正在保存9-roi图片,本次图片数量: 94
# 正在保存9-roi图片,本次图片数量: 95
# 正在保存9-roi图片,本次图片数量: 96
# 正在保存9-roi图片,本次图片数量: 97
# 正在保存9-roi图片,本次图片数量: 98
# 正在保存9-roi图片,本次图片数量: 99
# 正在保存9-roi图片,本次图片数量: 100
